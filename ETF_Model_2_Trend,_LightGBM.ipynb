# %% [markdown]
# ##LightGBM

# %% [markdown]
# A notebook demonstrating the use of K-means correlation clustering (HRP was experimented with but resulting clusters were not intuitive) to select features that characterise most risks. In this demonstration, the model was trained on data sourced from AlphaVantage and saved to flat files. Unfortunately the original data is no longer available.
#
# This is the training notebook for the trend component of ETF returns using LightGBM, several models have been used to forecast the noise component and I hope to load these in the near future.

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install optuna

import pandas as pd
import os
import numpy as np
import lightgbm as lgb
import optuna
from statsmodels.tsa.seasonal import STL
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor, as_completed
from sklearn.cluster import KMeans
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
# Out:
# Mounted at /content/drive
# Collecting optuna
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 3.6 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 22.4 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.27)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.10.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.2 alembic-1.13.1 colorlog-6.8.2 optuna-3.5.0

# %%
start_date, end_date = '2006-10-01', '2016-11-30'

volume = pd.read_csv('/content/drive/My Drive/Data/ETFs/volume.csv', parse_dates=['Date'], dayfirst=True).set_index('Date').loc[start_date:end_date]
close = pd.read_csv('/content/drive/My Drive/Data/ETFs/close.csv', parse_dates=['Date'], dayfirst=True).set_index('Date').loc[start_date:end_date]

# '_s' appended to names denotes structured
volume_levels_s = volume.reindex(pd.date_range(start=start_date, end=end_date, freq='D')).ffill()
close_levels_s = close.reindex(pd.date_range(start=start_date, end=end_date, freq='D')).ffill()
close_ln_s = close_levels_s.applymap(lambda x: np.log(x) if pd.notnull(x) else x)
close_lnreturns_s = close_ln_s.diff()

# %%
size = int(len(close_ln_s) * 0.7)

# in-sample dataframes
volume_levels, close_levels, close_ln, close_lnreturns = [df.iloc[:size] for df in [volume_levels_s, close_levels_s, close_ln_s, close_lnreturns_s]]

# out-of-sample dataframes (with '_oos' appended to names)
volume_levels_oos, close_levels_oos, close_ln_oos, close_lnreturns_oos = [df.iloc[size:] for df in [volume_levels_s, close_levels_s, close_ln_s, close_lnreturns_s]]

# %%
number_of_assets = 500 # number of securities to narrow by volume

high_volume = volume_levels.iloc[-100:].mean().sort_values(ascending=False).head(number_of_assets).index.tolist()

close_lnuniverse = close_ln.loc[:, close_ln.columns.intersection(high_volume)]
close_lnreturnsuniverse = close_lnreturns.loc[:, close_lnreturns.columns.intersection(high_volume)]

close_lnreturnsuniverse.iloc[-5:]
# Out:
#                  prf       pjp      ipff      iefa      sdog      ephe  \
# 2013-11-07 -0.012659 -0.007750 -0.003751 -0.015864 -0.014615 -0.032012
# 2013-11-08  0.013937  0.037765  0.004539  0.005077  0.008104  0.001219
# 2013-11-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2013-11-10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2013-11-11  0.001113  0.005041  0.002360  0.001699  0.001470 -0.011022
#
#                 urty       pbs       ugl       hys  ...      mint       oef  \
# 2013-11-07 -0.053835 -0.024271 -0.017029 -0.000380  ...  0.000206 -0.011431
# 2013-11-08  0.054905  0.022581 -0.031993 -0.001927  ... -0.000206  0.012677
# 2013-11-09  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2013-11-10  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2013-11-11  0.003839  0.000000 -0.003595 -0.001387  ...  0.000515  0.000397
#
#                  ipo       iat       ryf       pst       xbi      tdtt  \
# 2013-11-07 -0.027854 -0.009039 -0.010054 -0.005881 -0.018905 -0.002065
# 2013-11-08  0.011028  0.029312  0.016176  0.021285  0.040278  0.000826
# 2013-11-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2013-11-10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2013-11-11  0.002532 -0.004639  0.000970  0.000679  0.012011  0.000413
#
#                 ixus      bsch
# 2013-11-07 -0.012432  0.001347
# 2013-11-08  0.000000 -0.004001
# 2013-11-09  0.000000  0.000000
# 2013-11-10  0.000000  0.000000
# 2013-11-11  0.002499  0.000839
#
# [5 rows x 500 columns]

# %%
# absolute correlation
similarity = close_lnreturnsuniverse.corr().abs()

similarity = similarity.dropna(axis=0, how='all').dropna(axis=1, how='all')

scaler = StandardScaler()
scaled_data = scaler.fit_transform(similarity)

kmeans = KMeans(n_clusters=30, random_state=42)
clusters = kmeans.fit_predict(scaled_data)

clustered_assets = pd.DataFrame({'Asset': similarity.index, 'Cluster': clusters})
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
centroids = kmeans.cluster_centers_

closest_features = []
for i, centroid in enumerate(centroids):
    distances = np.linalg.norm(scaled_data[kmeans.labels_ == i] - centroid, axis=1)
    closest_index = np.argmin(distances)
    closest_feature = similarity.index[kmeans.labels_ == i][closest_index]
    closest_features.append(closest_feature)

log_prices = close_lnuniverse[closest_features]

log_prices
# Out:
#                  fbt      mint      sdog      sivr       iwc       fxy  \
# 2006-10-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2006-10-02  3.061333       NaN       NaN       NaN  3.876769       NaN
# 2006-10-03  3.059458       NaN       NaN       NaN  3.876562       NaN
# 2006-10-04  3.082598       NaN       NaN       NaN  3.894612       NaN
# 2006-10-05  3.095351       NaN       NaN       NaN  3.909981       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2013-11-07  4.108790  4.574824  3.367399  3.060115  4.176493  4.602467
# 2013-11-08  4.145830  4.574618  3.375503  3.054944  4.196149  4.590868
# 2013-11-09  4.145830  4.574618  3.375503  3.054944  4.196149  4.590868
# 2013-11-10  4.145830  4.574618  3.375503  3.054944  4.196149  4.590868
# 2013-11-11  4.154185  4.575134  3.376973  3.049747  4.197172  4.590361
#
#                  gsg       hys      bsch       tlt  ...       xle       shv  \
# 2006-10-01       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2006-10-02  3.720378       NaN       NaN  4.304416  ...  3.813748       NaN
# 2006-10-03  3.695855       NaN       NaN  4.303105  ...  3.776318       NaN
# 2006-10-04  3.705491       NaN       NaN  4.310370  ...  3.790917       NaN
# 2006-10-05  3.715034       NaN       NaN  4.303335  ...  3.809902       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2013-11-07  3.428813  4.462754  3.069912  4.561709  ...  4.339654  4.693364
# 2013-11-08  3.434954  4.460826  3.065911  4.537566  ...  4.354450  4.693364
# 2013-11-09  3.434954  4.460826  3.065911  4.537566  ...  4.354450  4.693364
# 2013-11-10  3.434954  4.460826  3.065911  4.537566  ...  4.354450  4.693364
# 2013-11-11  3.443618  4.459439  3.066750  4.533653  ...  4.356311  4.693456
#
#                  gvi       fpf       rsp      flrn       pbj      eido  \
# 2006-10-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2006-10-02       NaN       NaN  3.689904       NaN  2.653312       NaN
# 2006-10-03       NaN       NaN  3.687403       NaN  2.650068       NaN
# 2006-10-04       NaN       NaN  3.700857       NaN  2.663680       NaN
# 2006-10-05       NaN       NaN  3.706253       NaN  2.669448       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2013-11-07  4.636572  2.688120  4.151921  3.387977  3.192737  3.153420
# 2013-11-08  4.632785  2.668755  4.164741  3.387301  3.202421  3.163913
# 2013-11-09  4.632785  2.668755  4.164741  3.387301  3.202421  3.163913
# 2013-11-10  4.632785  2.668755  4.164741  3.387301  3.202421  3.163913
# 2013-11-11  4.631033  2.670141  4.166340  3.387977  3.200427  3.143290
#
#                  tfi      sjnk
# 2006-10-01       NaN       NaN
# 2006-10-02       NaN       NaN
# 2006-10-03       NaN       NaN
# 2006-10-04       NaN       NaN
# 2006-10-05       NaN       NaN
# ...              ...       ...
# 2013-11-07  3.728509  3.216673
# 2013-11-08  3.725356  3.216032
# 2013-11-09  3.725356  3.216032
# 2013-11-10  3.725356  3.216032
# 2013-11-11  3.722749  3.215631
#
# [2599 rows x 30 columns]

# %%
def apply_stl_to_column(series, period=7): # weekly seasonality
    if series.dropna().empty:
        return None, None
    stl = STL(series.dropna(), period=period, robust=True)  # drop leading NaNs
    result = stl.fit()
    combined_seasonal_residual = result.seasonal + result.resid  # combine seasonal and residual
    return result.trend, combined_seasonal_residual

trend_df = pd.DataFrame(index=log_prices.index)
combined_df = pd.DataFrame(index=log_prices.index)

# parallelisation
with ThreadPoolExecutor(max_workers=4) as executor:
    futures = {executor.submit(apply_stl_to_column, log_prices[col], 21): col for col in log_prices.columns}

    for future in as_completed(futures):
        col = futures[future]
        trend, combined_seasonal_residual = future.result()

        if trend is not None:
            trend_df[col] = pd.Series(trend, index=log_prices[col].dropna().index)
            combined_df[col] = pd.Series(combined_seasonal_residual, index=log_prices[col].dropna().index)

trend_df.iloc[-5:]
# Out:
#                 sdog      mint      sivr       fbt       iwc      bsch  \
# 2013-11-07  3.383675  4.574814  3.083438  4.164710  4.197830  3.069368
# 2013-11-08  3.384586  4.574865  3.083510  4.164675  4.197369  3.069549
# 2013-11-09  3.385483  4.574916  3.083562  4.164629  4.196886  3.069725
# 2013-11-10  3.386365  4.574966  3.083594  4.164572  4.196380  3.069895
# 2013-11-11  3.387233  4.575016  3.083606  4.164503  4.195855  3.070061
#
#                  fxy       gsg       hys       dgp  ...       fpf       xle  \
# 2013-11-07  4.598322  3.438264  4.463039  3.421890  ...  2.687065  4.354941
# 2013-11-08  4.598062  3.435989  4.463310  3.422010  ...  2.686825  4.355204
# 2013-11-09  4.597800  3.433705  4.463576  3.422078  ...  2.686586  4.355450
# 2013-11-10  4.597536  3.431415  4.463837  3.422094  ...  2.686347  4.355679
# 2013-11-11  4.597269  3.429119  4.464093  3.422058  ...  2.686108  4.355892
#
#                  shv       gvi      flrn       pbj       rsp      sjnk  \
# 2013-11-07  4.693392  4.636301  3.387827  3.210454  4.167552  3.216370
# 2013-11-08  4.693387  4.636416  3.387826  3.210736  4.168431  3.216643
# 2013-11-09  4.693381  4.636528  3.387823  3.211002  4.169295  3.216914
# 2013-11-10  4.693376  4.636636  3.387819  3.211255  4.170145  3.217183
# 2013-11-11  4.693370  4.636740  3.387812  3.211494  4.170981  3.217449
#
#                 eido       tfi
# 2013-11-07  3.178419  3.730617
# 2013-11-08  3.176619  3.731096
# 2013-11-09  3.174810  3.731571
# 2013-11-10  3.172993  3.732042
# 2013-11-11  3.171169  3.732509
#
# [5 rows x 30 columns]

# %% [markdown]
# Training and Validation. This block measures the average MAE across all observations h-steps ahead. The goal is to find params that are robust across asset classes.

# %%
data_subset = trend_df

n_validation_windows = 3
n_forecast = 30

def objective(trial):
    # hyperparameters to tune
    num_leaves = trial.suggest_int('num_leaves', 40, 80)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3)
    n_estimators = trial.suggest_int('n_estimators', 200, 400)
    max_depth = trial.suggest_int('max_depth', 1, 10)
    min_child_samples = trial.suggest_int('min_child_samples', 5, 20)
    feature_fraction = trial.suggest_float('feature_fraction', 0.5, 1.0)
    bagging_fraction = trial.suggest_float('bagging_fraction', 0.3, 0.9)
    bagging_freq = trial.suggest_int('bagging_freq', 2, 9)
    lambda_l1 = trial.suggest_float('lambda_l1', 1e-2, 3, log=True)
    lambda_l2 = trial.suggest_float('lambda_l2', 1e-5, 3, log=True)
    min_gain_to_split = trial.suggest_float('min_gain_to_split', 0.0, 0.5)

    aggregated_original_maes = []

    for column in data_subset.columns:
        series = data_subset[column].dropna()
        if len(series) < (n_validation_windows * n_forecast):
            continue

        n_validation = n_validation_windows * n_forecast
        train_series = series[:-n_validation]
        validation_series = series[-n_validation:]

        scaler = StandardScaler(with_mean=True, with_std=False)
        train_scaled = scaler.fit_transform(train_series.values.reshape(-1, 1)).flatten()

        train_x = np.arange(len(train_scaled)).reshape(-1, 1)
        train_y = train_scaled

        lgb_train = lgb.Dataset(train_x, train_y)

        # lightGBM parameters
        params = {
            'objective': 'regression',
            'metric': 'mae',
            'num_leaves': num_leaves,
            'learning_rate': learning_rate,
            'max_depth': max_depth,
            'min_child_samples': min_child_samples,
            'feature_fraction': feature_fraction,
            'bagging_fraction': bagging_fraction,
            'bagging_freq': bagging_freq,
            'lambda_l1': lambda_l1,
            'lambda_l2': lambda_l2,
            'min_gain_to_split': min_gain_to_split,
            'verbose': -1
        }

        # train the model
        gbm = lgb.train(params, lgb_train, num_boost_round=n_estimators)

        mae = walk_forward_forecast_and_retrain(gbm, scaler, n_forecast, series, n_validation_windows)

        aggregated_original_maes.append(mae)

    return np.mean(aggregated_original_maes)

def walk_forward_forecast_and_retrain(model, scaler, n_forecast, series, n_validation_windows):
    n_validation = n_validation_windows * n_forecast
    train_series = series[:-n_validation]
    validation_series = series[-n_validation:]

    mae_values = []

    for i in range(n_validation_windows):
        start_idx = i * n_forecast
        end_idx = start_idx + n_forecast
        current_validation = validation_series[start_idx:end_idx]

        # forecast for the next period
        validation_x = np.arange(len(train_series) + start_idx, len(train_series) + end_idx).reshape(-1, 1)
        predicted = model.predict(validation_x)
        predicted = scaler.inverse_transform(predicted.reshape(-1, 1)).flatten()

        # calculate MAE for the forecast and the actual values
        mae = mean_absolute_error(current_validation.values, predicted)
        mae_values.append(mae)

    return np.mean(mae_values)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=200)

print(f'best trial: {study.best_trial.number}')
print(f'best MAE: {study.best_trial.value}')
print(f'best hyperparameters: {study.best_trial.params}')
# Out:
# [I 2024-03-01 19:14:48,372] A new study created in memory with name: no-name-c5f9ac8c-89dc-4e10-8f44-730c27c852be
# [I 2024-03-01 19:14:49,316] Trial 0 finished with value: 0.07565764935059792 and parameters: {'num_leaves': 73, 'learning_rate': 0.11984163912951513, 'n_estimators': 302, 'max_depth': 2, 'min_child_samples': 8, 'feature_fraction': 0.6873834334466675, 'bagging_fraction': 0.5656143085464131, 'bagging_freq': 6, 'lambda_l1': 0.27191237130800383, 'lambda_l2': 3.318805847354643e-05, 'min_gain_to_split': 0.4658320214927204}. Best is trial 0 with value: 0.07565764935059792.
# [I 2024-03-01 19:14:49,689] Trial 1 finished with value: 0.0517871645771966 and parameters: {'num_leaves': 44, 'learning_rate': 0.10107295912662707, 'n_estimators': 354, 'max_depth': 2, 'min_child_samples': 5, 'feature_fraction': 0.875057249656317, 'bagging_fraction': 0.8500070925821641, 'bagging_freq': 7, 'lambda_l1': 0.22957559110109169, 'lambda_l2': 0.023137155474268874, 'min_gain_to_split': 0.07726650530464851}. Best is trial 1 with value: 0.0517871645771966.
# [I 2024-03-01 19:14:50,007] Trial 2 finished with value: 0.054291858778395076 and parameters: {'num_leaves': 72, 'learning_rate': 0.08545216811047295, 'n_estimators': 213, 'max_depth': 2, 'min_child_samples': 17, 'feature_fraction': 0.7742002928500329, 'bagging_fraction': 0.8514242991903112, 'bagging_freq': 4, 'lambda_l1': 0.10757066749716437, 'lambda_l2': 2.151294206798512e-05, 'min_gain_to_split': 0.10356457050015233}. Best is trial 1 with value: 0.0517871645771966.
# [I 2024-03-01 19:14:50,331] Trial 3 finished with value: 0.040293229709725896 and parameters: {'num_leaves': 79, 'learning_rate': 0.14267980521575357, 'n_estimators': 272, 'max_depth': 3, 'min_child_samples': 5, 'feature_fraction': 0.8095523101530583, 'bagging_fraction': 0.5096549062008583, 'bagging_freq': 7, 'lambda_l1': 0.07008219730937683, 'lambda_l2': 0.007428274718132228, 'min_gain_to_split': 0.012213080160180467}. Best is trial 3 with value: 0.040293229709725896.
# [I 2024-03-01 19:14:50,741] Trial 4 finished with value: 0.06430513815183629 and parameters: {'num_leaves': 78, 'learning_rate': 0.280826607245583, 'n_estimators': 359, 'max_depth': 3, 'min_child_samples': 15, 'feature_fraction': 0.9175089209258109, 'bagging_fraction': 0.7259238623431561, 'bagging_freq': 2, 'lambda_l1': 0.32573597288471984, 'lambda_l2': 0.0010483216503582207, 'min_gain_to_split': 0.3142487143183611}. Best is trial 3 with value: 0.040293229709725896.
# [I 2024-03-01 19:14:51,055] Trial 5 finished with value: 0.0773781429289996 and parameters: {'num_leaves': 63, 'learning_rate': 0.2426626609714294, 'n_estimators': 292, 'max_depth': 1, 'min_child_samples': 13, 'feature_fraction': 0.7845141777544322, 'bagging_fraction': 0.4246527769820958, 'bagging_freq': 7, 'lambda_l1': 0.5294436072793336, 'lambda_l2': 0.013416642756266858, 'min_gain_to_split': 0.3540416716592512}. Best is trial 3 with value: 0.040293229709725896.
# [I 2024-03-01 19:14:51,433] Trial 6 finished with value: 0.06743566455325195 and parameters: {'num_leaves': 66, 'learning_rate': 0.2460400384540036, 'n_estimators': 359, 'max_depth': 6, 'min_child_samples': 14, 'feature_fraction': 0.7274149047416602, 'bagging_fraction': 0.7533377940185666, 'bagging_freq': 9, 'lambda_l1': 0.02053938096346054, 'lambda_l2': 1.3302033812379289e-05, 'min_gain_to_split': 0.4286889708285747}. Best is trial 3 with value: 0.040293229709725896.
# [I 2024-03-01 19:14:51,806] Trial 7 finished with value: 0.07907087431608906 and parameters: {'num_leaves': 71, 'learning_rate': 0.24230582876771026, 'n_estimators': 368, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.8142183546134729, 'bagging_fraction': 0.571240022737719, 'bagging_freq': 4, 'lambda_l1': 1.992726791142546, 'lambda_l2': 0.0035987353761570825, 'min_gain_to_split': 0.41338856432013105}. Best is trial 3 with value: 0.040293229709725896.
# [I 2024-03-01 19:14:52,085] Trial 8 finished with value: 0.07550608485468319 and parameters: {'num_leaves': 47, 'learning_rate': 0.10808653823995897, 'n_estimators': 215, 'max_depth': 1, 'min_child_samples': 10, 'feature_fraction': 0.6077400115467653, 'bagging_fraction': 0.6236221272576172, 'bagging_freq': 8, 'lambda_l1': 0.018712051325776802, 'lambda_l2': 0.1815563752971318, 'min_gain_to_split': 0.48984934197571367}. Best is trial 3 with value: 0.040293229709725896.
# [I 2024-03-01 19:14:52,393] Trial 9 finished with value: 0.06679679706088174 and parameters: {'num_leaves': 44, 'learning_rate': 0.08767986320275982, 'n_estimators': 232, 'max_depth': 9, 'min_child_samples': 11, 'feature_fraction': 0.6246306285747554, 'bagging_fraction': 0.5658577224051249, 'bagging_freq': 3, 'lambda_l1': 0.016074641451592243, 'lambda_l2': 0.0017910994439024736, 'min_gain_to_split': 0.26805804679287043}. Best is trial 3 with value: 0.040293229709725896.
# [I 2024-03-01 19:14:53,149] Trial 10 finished with value: 0.042429937755555674 and parameters: {'num_leaves': 56, 'learning_rate': 0.020393697974390973, 'n_estimators': 268, 'max_depth': 4, 'min_child_samples': 20, 'feature_fraction': 0.9972453949645135, 'bagging_fraction': 0.4003476928169697, 'bagging_freq': 5, 'lambda_l1': 0.06628705176929993, 'lambda_l2': 0.7483034541378221, 'min_gain_to_split': 0.010524549833056784}. Best is trial 3 with value: 0.040293229709725896.
# [I 2024-03-01 19:14:53,927] Trial 11 finished with value: 0.039156435823488614 and parameters: {'num_leaves': 54, 'learning_rate': 0.027076594994901518, 'n_estimators': 268, 'max_depth': 4, 'min_child_samples': 20, 'feature_fraction': 0.9887763157959097, 'bagging_fraction': 0.3503300600158911, 'bagging_freq': 5, 'lambda_l1': 0.05315449522950755, 'lambda_l2': 2.455293669494137, 'min_gain_to_split': 0.0022219662137698167}. Best is trial 11 with value: 0.039156435823488614.
# [I 2024-03-01 19:14:54,438] Trial 12 finished with value: 0.06993960435218831 and parameters: {'num_leaves': 54, 'learning_rate': 0.016119366464982476, 'n_estimators': 263, 'max_depth': 5, 'min_child_samples': 20, 'feature_fraction': 0.985139785888512, 'bagging_fraction': 0.31188654170581476, 'bagging_freq': 6, 'lambda_l1': 0.050671192831907456, 'lambda_l2': 2.489487604873761, 'min_gain_to_split': 0.16190582040521215}. Best is trial 11 with value: 0.039156435823488614.
# [I 2024-03-01 19:14:54,833] Trial 13 finished with value: 0.03345718344637994 and parameters: {'num_leaves': 53, 'learning_rate': 0.18738785886935472, 'n_estimators': 319, 'max_depth': 8, 'min_child_samples': 8, 'feature_fraction': 0.870182327547252, 'bagging_fraction': 0.4478297226836979, 'bagging_freq': 5, 'lambda_l1': 0.05149156236401054, 'lambda_l2': 0.00021605349638499755, 'min_gain_to_split': 0.0021987601586469507}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:14:55,187] Trial 14 finished with value: 0.06866003117725324 and parameters: {'num_leaves': 51, 'learning_rate': 0.1870045637872333, 'n_estimators': 321, 'max_depth': 8, 'min_child_samples': 8, 'feature_fraction': 0.8960852403872039, 'bagging_fraction': 0.3151058784646574, 'bagging_freq': 5, 'lambda_l1': 0.03770557812836688, 'lambda_l2': 0.00017101490929367176, 'min_gain_to_split': 0.1813543300895129}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:14:55,555] Trial 15 finished with value: 0.0634515275327158 and parameters: {'num_leaves': 58, 'learning_rate': 0.18638686004233737, 'n_estimators': 327, 'max_depth': 8, 'min_child_samples': 17, 'feature_fraction': 0.9450174947854426, 'bagging_fraction': 0.42105842992618414, 'bagging_freq': 4, 'lambda_l1': 0.8812221183320168, 'lambda_l2': 0.00035645920319726804, 'min_gain_to_split': 0.09767767546145643}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:14:55,965] Trial 16 finished with value: 0.06531665915319965 and parameters: {'num_leaves': 51, 'learning_rate': 0.049791021380509976, 'n_estimators': 244, 'max_depth': 10, 'min_child_samples': 8, 'feature_fraction': 0.8502800347488642, 'bagging_fraction': 0.4726342170369778, 'bagging_freq': 2, 'lambda_l1': 0.12253900260845323, 'lambda_l2': 0.09224442075187925, 'min_gain_to_split': 0.18230954909518754}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:14:56,337] Trial 17 finished with value: 0.0480010928422923 and parameters: {'num_leaves': 61, 'learning_rate': 0.1952080117703509, 'n_estimators': 399, 'max_depth': 7, 'min_child_samples': 11, 'feature_fraction': 0.5199744245484588, 'bagging_fraction': 0.3790338029928816, 'bagging_freq': 5, 'lambda_l1': 0.03133565126112225, 'lambda_l2': 0.00024960566965689387, 'min_gain_to_split': 0.03534520089411372}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:14:56,690] Trial 18 finished with value: 0.059945889110313066 and parameters: {'num_leaves': 50, 'learning_rate': 0.161423906974559, 'n_estimators': 298, 'max_depth': 5, 'min_child_samples': 18, 'feature_fraction': 0.9538878465368156, 'bagging_fraction': 0.4906913556783415, 'bagging_freq': 3, 'lambda_l1': 0.010327612129131032, 'lambda_l2': 6.717216561173238e-05, 'min_gain_to_split': 0.14229490800907818}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:14:57,061] Trial 19 finished with value: 0.07198877146885276 and parameters: {'num_leaves': 42, 'learning_rate': 0.05898991282947795, 'n_estimators': 333, 'max_depth': 7, 'min_child_samples': 15, 'feature_fraction': 0.850764450980839, 'bagging_fraction': 0.3500125075807013, 'bagging_freq': 6, 'lambda_l1': 0.12251336326874787, 'lambda_l2': 0.052200891933124514, 'min_gain_to_split': 0.2370270466851}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:14:57,398] Trial 20 finished with value: 0.04802466206210411 and parameters: {'num_leaves': 40, 'learning_rate': 0.15485067077971193, 'n_estimators': 247, 'max_depth': 10, 'min_child_samples': 10, 'feature_fraction': 0.9214924459471663, 'bagging_fraction': 0.6243295646152226, 'bagging_freq': 3, 'lambda_l1': 0.03271546450844987, 'lambda_l2': 0.3999924096121421, 'min_gain_to_split': 0.05243111500127688}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:14:58,354] Trial 21 finished with value: 0.045834516155871745 and parameters: {'num_leaves': 65, 'learning_rate': 0.13556092131568293, 'n_estimators': 277, 'max_depth': 4, 'min_child_samples': 6, 'feature_fraction': 0.7294302195250852, 'bagging_fraction': 0.5055900847549708, 'bagging_freq': 7, 'lambda_l1': 0.06832067789378117, 'lambda_l2': 0.00810005801758839, 'min_gain_to_split': 0.02817978238665608}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:14:59,725] Trial 22 finished with value: 0.03759022954085072 and parameters: {'num_leaves': 54, 'learning_rate': 0.05523510547189013, 'n_estimators': 287, 'max_depth': 4, 'min_child_samples': 7, 'feature_fraction': 0.8035332405431067, 'bagging_fraction': 0.4624930431510475, 'bagging_freq': 9, 'lambda_l1': 0.0771913884783119, 'lambda_l2': 0.0007988623345606407, 'min_gain_to_split': 0.004784956416242371}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:00,150] Trial 23 finished with value: 0.05683009533147024 and parameters: {'num_leaves': 54, 'learning_rate': 0.05216024657430458, 'n_estimators': 312, 'max_depth': 4, 'min_child_samples': 7, 'feature_fraction': 0.8638893488090039, 'bagging_fraction': 0.44185994120054933, 'bagging_freq': 9, 'lambda_l1': 0.14220139007358876, 'lambda_l2': 0.0012018052864648306, 'min_gain_to_split': 0.07205263310920369}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:01,409] Trial 24 finished with value: 0.0414906924242802 and parameters: {'num_leaves': 59, 'learning_rate': 0.01004137627669326, 'n_estimators': 285, 'max_depth': 5, 'min_child_samples': 10, 'feature_fraction': 0.6736802574305819, 'bagging_fraction': 0.3618666679818393, 'bagging_freq': 8, 'lambda_l1': 0.09013556944016658, 'lambda_l2': 0.0004688951172141981, 'min_gain_to_split': 0.0018373552150213685}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:01,921] Trial 25 finished with value: 0.05868404530374618 and parameters: {'num_leaves': 48, 'learning_rate': 0.040182626645164844, 'n_estimators': 342, 'max_depth': 7, 'min_child_samples': 7, 'feature_fraction': 0.9540281478140346, 'bagging_fraction': 0.4551061935140662, 'bagging_freq': 5, 'lambda_l1': 0.0442521481855519, 'lambda_l2': 0.0001334550921014574, 'min_gain_to_split': 0.09727772768477483}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:02,292] Trial 26 finished with value: 0.06085289053070501 and parameters: {'num_leaves': 54, 'learning_rate': 0.06163460789172588, 'n_estimators': 260, 'max_depth': 3, 'min_child_samples': 12, 'feature_fraction': 0.8196497437241479, 'bagging_fraction': 0.5294368285978753, 'bagging_freq': 8, 'lambda_l1': 0.19115740398411668, 'lambda_l2': 0.0030003669567921034, 'min_gain_to_split': 0.11794390395653442}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:02,861] Trial 27 finished with value: 0.04173364104366861 and parameters: {'num_leaves': 57, 'learning_rate': 0.07569342625730147, 'n_estimators': 310, 'max_depth': 6, 'min_child_samples': 9, 'feature_fraction': 0.757128291716995, 'bagging_fraction': 0.3015691061767106, 'bagging_freq': 4, 'lambda_l1': 0.42435731916436303, 'lambda_l2': 0.000829812979172706, 'min_gain_to_split': 0.0002979249485238755}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:03,163] Trial 28 finished with value: 0.047003781946345594 and parameters: {'num_leaves': 48, 'learning_rate': 0.2144771745874201, 'n_estimators': 200, 'max_depth': 4, 'min_child_samples': 7, 'feature_fraction': 0.9022624871201704, 'bagging_fraction': 0.7015101196751488, 'bagging_freq': 6, 'lambda_l1': 0.022619856199200213, 'lambda_l2': 6.573107726900255e-05, 'min_gain_to_split': 0.04901618046076955}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:03,509] Trial 29 finished with value: 0.06919702581139911 and parameters: {'num_leaves': 68, 'learning_rate': 0.12728659819378108, 'n_estimators': 285, 'max_depth': 8, 'min_child_samples': 9, 'feature_fraction': 0.6669283219239299, 'bagging_fraction': 0.3564079643115616, 'bagging_freq': 5, 'lambda_l1': 0.05624076437399464, 'lambda_l2': 8.339281147456088e-05, 'min_gain_to_split': 0.22229609504741302}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:04,021] Trial 30 finished with value: 0.06530533752589973 and parameters: {'num_leaves': 61, 'learning_rate': 0.029966776625257506, 'n_estimators': 304, 'max_depth': 9, 'min_child_samples': 18, 'feature_fraction': 0.7120905536092837, 'bagging_fraction': 0.3938184365610564, 'bagging_freq': 6, 'lambda_l1': 0.08601985965138692, 'lambda_l2': 0.035859616208428695, 'min_gain_to_split': 0.13814348148707764}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:04,360] Trial 31 finished with value: 0.05187847865334265 and parameters: {'num_leaves': 80, 'learning_rate': 0.15945065468985373, 'n_estimators': 276, 'max_depth': 3, 'min_child_samples': 6, 'feature_fraction': 0.8094743707707611, 'bagging_fraction': 0.5331383428662044, 'bagging_freq': 7, 'lambda_l1': 0.0680371361976953, 'lambda_l2': 1.579391278109101, 'min_gain_to_split': 0.05532927415688285}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:04,685] Trial 32 finished with value: 0.049318116179323884 and parameters: {'num_leaves': 53, 'learning_rate': 0.21021463208185462, 'n_estimators': 245, 'max_depth': 3, 'min_child_samples': 5, 'feature_fraction': 0.8182441508145184, 'bagging_fraction': 0.4700842963803629, 'bagging_freq': 9, 'lambda_l1': 0.1765158293692756, 'lambda_l2': 0.007846812645880464, 'min_gain_to_split': 0.029570343038305837}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:05,034] Trial 33 finished with value: 0.05585520751705267 and parameters: {'num_leaves': 76, 'learning_rate': 0.14244594667519106, 'n_estimators': 297, 'max_depth': 2, 'min_child_samples': 6, 'feature_fraction': 0.7850489604181979, 'bagging_fraction': 0.5264324925990778, 'bagging_freq': 7, 'lambda_l1': 0.027747282265283026, 'lambda_l2': 3.515849509226152e-05, 'min_gain_to_split': 0.08985593950693262}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:05,382] Trial 34 finished with value: 0.05494847793060683 and parameters: {'num_leaves': 56, 'learning_rate': 0.09222109901372955, 'n_estimators': 254, 'max_depth': 2, 'min_child_samples': 5, 'feature_fraction': 0.8769953154725212, 'bagging_fraction': 0.5960131966211054, 'bagging_freq': 8, 'lambda_l1': 0.2825916465653961, 'lambda_l2': 0.0005041354200291276, 'min_gain_to_split': 0.06493389950133582}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:05,770] Trial 35 finished with value: 0.04475188259778243 and parameters: {'num_leaves': 46, 'learning_rate': 0.07147000194854705, 'n_estimators': 233, 'max_depth': 4, 'min_child_samples': 7, 'feature_fraction': 0.8372277841236186, 'bagging_fraction': 0.4300455001057272, 'bagging_freq': 7, 'lambda_l1': 0.08987925408013224, 'lambda_l2': 0.02197261317032507, 'min_gain_to_split': 0.016181255104471038}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:06,278] Trial 36 finished with value: 0.05473385279507295 and parameters: {'num_leaves': 69, 'learning_rate': 0.03340864885074186, 'n_estimators': 286, 'max_depth': 5, 'min_child_samples': 15, 'feature_fraction': 0.8774267360998369, 'bagging_fraction': 0.5011290943053798, 'bagging_freq': 4, 'lambda_l1': 0.040461038514160635, 'lambda_l2': 0.002271966607161338, 'min_gain_to_split': 0.07341325369522554}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:06,633] Trial 37 finished with value: 0.05373070199921625 and parameters: {'num_leaves': 63, 'learning_rate': 0.2942900298763026, 'n_estimators': 271, 'max_depth': 3, 'min_child_samples': 8, 'feature_fraction': 0.7503081983364335, 'bagging_fraction': 0.8179876060147278, 'bagging_freq': 6, 'lambda_l1': 0.22140876273866136, 'lambda_l2': 2.2820362116784554e-05, 'min_gain_to_split': 0.12053762562940457}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:07,062] Trial 38 finished with value: 0.06896972698200292 and parameters: {'num_leaves': 52, 'learning_rate': 0.101874496259648, 'n_estimators': 348, 'max_depth': 1, 'min_child_samples': 9, 'feature_fraction': 0.7901460736882248, 'bagging_fraction': 0.6649403282183899, 'bagging_freq': 9, 'lambda_l1': 0.011894837276632942, 'lambda_l2': 0.31918991573452077, 'min_gain_to_split': 0.3555155281082798}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:07,430] Trial 39 finished with value: 0.07463219825770878 and parameters: {'num_leaves': 74, 'learning_rate': 0.11860531375460995, 'n_estimators': 318, 'max_depth': 2, 'min_child_samples': 13, 'feature_fraction': 0.9243822701887683, 'bagging_fraction': 0.4120044545094513, 'bagging_freq': 8, 'lambda_l1': 2.833385982382746, 'lambda_l2': 1.1553367574231794e-05, 'min_gain_to_split': 0.03527208328888589}. Best is trial 13 with value: 0.03345718344637994.
# [I 2024-03-01 19:15:07,864] Trial 40 finished with value: 0.030081887815830124 and parameters: {'num_leaves': 45, 'learning_rate': 0.25985030849854607, 'n_estimators': 381, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.7670199889451264, 'bagging_fraction': 0.5545558214089489, 'bagging_freq': 4, 'lambda_l1': 0.023755647709557633, 'lambda_l2': 0.004353922166647601, 'min_gain_to_split': 0.0007465252107883981}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:08,273] Trial 41 finished with value: 0.03703000770934738 and parameters: {'num_leaves': 56, 'learning_rate': 0.26295597772825113, 'n_estimators': 375, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.7696291602065891, 'bagging_fraction': 0.5496988144007099, 'bagging_freq': 4, 'lambda_l1': 0.024400384972732527, 'lambda_l2': 0.013009159025810848, 'min_gain_to_split': 0.009800537763565077}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:08,666] Trial 42 finished with value: 0.03326051295895297 and parameters: {'num_leaves': 46, 'learning_rate': 0.2686974793957768, 'n_estimators': 383, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.7659063281058324, 'bagging_fraction': 0.593399029106044, 'bagging_freq': 4, 'lambda_l1': 0.013938098604086825, 'lambda_l2': 0.005112193440356077, 'min_gain_to_split': 0.004785851218205513}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:09,082] Trial 43 finished with value: 0.04622721897786661 and parameters: {'num_leaves': 45, 'learning_rate': 0.2607690865528014, 'n_estimators': 378, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.7065469778765664, 'bagging_fraction': 0.5592812521398638, 'bagging_freq': 4, 'lambda_l1': 0.0142559941860814, 'lambda_l2': 0.00444493398842483, 'min_gain_to_split': 0.04094316020505573}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:09,720] Trial 44 finished with value: 0.04968418731664504 and parameters: {'num_leaves': 49, 'learning_rate': 0.26818563116570304, 'n_estimators': 385, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.769537430895254, 'bagging_fraction': 0.6045234917147569, 'bagging_freq': 3, 'lambda_l1': 0.023657072380155967, 'lambda_l2': 0.016026556779512403, 'min_gain_to_split': 0.07627541299072871}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:11,394] Trial 45 finished with value: 0.04126136390058189 and parameters: {'num_leaves': 42, 'learning_rate': 0.2268290298994669, 'n_estimators': 372, 'max_depth': 7, 'min_child_samples': 6, 'feature_fraction': 0.7348850750109941, 'bagging_fraction': 0.6574169010969585, 'bagging_freq': 4, 'lambda_l1': 0.012896372789239299, 'lambda_l2': 0.0011430771786370363, 'min_gain_to_split': 0.023287421993014666}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:11,793] Trial 46 finished with value: 0.06572052519914975 and parameters: {'num_leaves': 46, 'learning_rate': 0.29773182438851264, 'n_estimators': 396, 'max_depth': 5, 'min_child_samples': 5, 'feature_fraction': 0.795702195082267, 'bagging_fraction': 0.5621476710360234, 'bagging_freq': 3, 'lambda_l1': 0.018888226031466844, 'lambda_l2': 0.010909848549802351, 'min_gain_to_split': 0.3150763270777516}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:12,258] Trial 47 finished with value: 0.032278196761774625 and parameters: {'num_leaves': 40, 'learning_rate': 0.2520488963930198, 'n_estimators': 385, 'max_depth': 7, 'min_child_samples': 8, 'feature_fraction': 0.7677325000918294, 'bagging_fraction': 0.5830230477251771, 'bagging_freq': 4, 'lambda_l1': 0.026419882124849307, 'lambda_l2': 0.005161775112094357, 'min_gain_to_split': 0.0026825556484011727}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:12,651] Trial 48 finished with value: 0.04631738894579552 and parameters: {'num_leaves': 42, 'learning_rate': 0.25176119030308697, 'n_estimators': 361, 'max_depth': 7, 'min_child_samples': 8, 'feature_fraction': 0.6464354012145102, 'bagging_fraction': 0.6469872955276367, 'bagging_freq': 4, 'lambda_l1': 0.01620363565135685, 'lambda_l2': 0.005127417860432054, 'min_gain_to_split': 0.05625358128265575}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:13,109] Trial 49 finished with value: 0.06907107450240475 and parameters: {'num_leaves': 44, 'learning_rate': 0.27976934574374973, 'n_estimators': 388, 'max_depth': 8, 'min_child_samples': 6, 'feature_fraction': 0.5761310231068895, 'bagging_fraction': 0.5902565402005036, 'bagging_freq': 2, 'lambda_l1': 0.023371260352202154, 'lambda_l2': 0.07359863801838418, 'min_gain_to_split': 0.4300698067250659}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:13,511] Trial 50 finished with value: 0.0405218910476211 and parameters: {'num_leaves': 40, 'learning_rate': 0.233146077050859, 'n_estimators': 367, 'max_depth': 9, 'min_child_samples': 5, 'feature_fraction': 0.7619053283406199, 'bagging_fraction': 0.6835884873729735, 'bagging_freq': 3, 'lambda_l1': 0.028552595132063215, 'lambda_l2': 0.02271995668336068, 'min_gain_to_split': 0.02406385621867513}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:13,936] Trial 51 finished with value: 0.03291985477549125 and parameters: {'num_leaves': 42, 'learning_rate': 0.2742890409390172, 'n_estimators': 381, 'max_depth': 6, 'min_child_samples': 7, 'feature_fraction': 0.702114616980078, 'bagging_fraction': 0.6235698604118926, 'bagging_freq': 5, 'lambda_l1': 0.01706703680707107, 'lambda_l2': 0.0018831914510288924, 'min_gain_to_split': 0.0037614233272103316}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:14,350] Trial 52 finished with value: 0.031171329608199717 and parameters: {'num_leaves': 43, 'learning_rate': 0.27647800686616714, 'n_estimators': 381, 'max_depth': 6, 'min_child_samples': 7, 'feature_fraction': 0.6920449800807907, 'bagging_fraction': 0.7224891377414268, 'bagging_freq': 5, 'lambda_l1': 0.016795701075597313, 'lambda_l2': 0.0017921044946307945, 'min_gain_to_split': 0.0019842417639881734}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:14,756] Trial 53 finished with value: 0.04398296020085731 and parameters: {'num_leaves': 43, 'learning_rate': 0.2807728345240673, 'n_estimators': 387, 'max_depth': 7, 'min_child_samples': 9, 'feature_fraction': 0.7019621891474704, 'bagging_fraction': 0.7442331474838302, 'bagging_freq': 5, 'lambda_l1': 0.010341048227534986, 'lambda_l2': 0.002014516969072976, 'min_gain_to_split': 0.043984856523280436}. Best is trial 40 with value: 0.030081887815830124.
# [I 2024-03-01 19:15:15,252] Trial 54 finished with value: 0.02890023369751856 and parameters: {'num_leaves': 40, 'learning_rate': 0.25152620949535853, 'n_estimators': 353, 'max_depth': 6, 'min_child_samples': 8, 'feature_fraction': 0.6786807410682225, 'bagging_fraction': 0.6302281342525461, 'bagging_freq': 5, 'lambda_l1': 0.01580541137057933, 'lambda_l2': 0.002850819938137912, 'min_gain_to_split': 6.4944091135841e-05}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:15,639] Trial 55 finished with value: 0.03974100536158351 and parameters: {'num_leaves': 40, 'learning_rate': 0.2513605227034962, 'n_estimators': 352, 'max_depth': 6, 'min_child_samples': 7, 'feature_fraction': 0.684240284470428, 'bagging_fraction': 0.7794402268213877, 'bagging_freq': 5, 'lambda_l1': 0.01645639986502673, 'lambda_l2': 0.002680171292135406, 'min_gain_to_split': 0.022894372313503542}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:16,082] Trial 56 finished with value: 0.05166922175543165 and parameters: {'num_leaves': 41, 'learning_rate': 0.27206789567248685, 'n_estimators': 382, 'max_depth': 6, 'min_child_samples': 8, 'feature_fraction': 0.6509716567987993, 'bagging_fraction': 0.6294948989324167, 'bagging_freq': 4, 'lambda_l1': 0.017972488159100762, 'lambda_l2': 0.005008039894101918, 'min_gain_to_split': 0.08904873072426185}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:16,525] Trial 57 finished with value: 0.029629952223770142 and parameters: {'num_leaves': 44, 'learning_rate': 0.28980904456386486, 'n_estimators': 396, 'max_depth': 7, 'min_child_samples': 11, 'feature_fraction': 0.6200611168621695, 'bagging_fraction': 0.6873797786978741, 'bagging_freq': 5, 'lambda_l1': 0.01351799553135224, 'lambda_l2': 0.0014443876811350864, 'min_gain_to_split': 0.000258553549001451}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:16,989] Trial 58 finished with value: 0.04701578022605723 and parameters: {'num_leaves': 44, 'learning_rate': 0.290452409417575, 'n_estimators': 395, 'max_depth': 7, 'min_child_samples': 10, 'feature_fraction': 0.6281892629180433, 'bagging_fraction': 0.695171702490466, 'bagging_freq': 5, 'lambda_l1': 0.03385535363230044, 'lambda_l2': 0.0013081278411391738, 'min_gain_to_split': 0.05806579327116977}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:17,384] Trial 59 finished with value: 0.043222385860824414 and parameters: {'num_leaves': 43, 'learning_rate': 0.23880069120993594, 'n_estimators': 365, 'max_depth': 5, 'min_child_samples': 11, 'feature_fraction': 0.5820710996356244, 'bagging_fraction': 0.7239184929547993, 'bagging_freq': 5, 'lambda_l1': 0.010704043826317733, 'lambda_l2': 0.0005399051810119084, 'min_gain_to_split': 0.03737972247939779}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:17,806] Trial 60 finished with value: 0.05083256541042794 and parameters: {'num_leaves': 41, 'learning_rate': 0.28509024118028353, 'n_estimators': 399, 'max_depth': 7, 'min_child_samples': 12, 'feature_fraction': 0.5910032137700876, 'bagging_fraction': 0.8926139495428729, 'bagging_freq': 6, 'lambda_l1': 0.01951189062307805, 'lambda_l2': 0.001628320573895672, 'min_gain_to_split': 0.11850852352050216}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:18,273] Trial 61 finished with value: 0.0297295019588139 and parameters: {'num_leaves': 46, 'learning_rate': 0.25870420962708013, 'n_estimators': 391, 'max_depth': 6, 'min_child_samples': 7, 'feature_fraction': 0.7232888584292078, 'bagging_fraction': 0.6103897437411613, 'bagging_freq': 4, 'lambda_l1': 0.013707481888205609, 'lambda_l2': 0.0033906415078732645, 'min_gain_to_split': 0.0005043685578815949}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:18,672] Trial 62 finished with value: 0.040506153342929875 and parameters: {'num_leaves': 45, 'learning_rate': 0.2563678372938851, 'n_estimators': 391, 'max_depth': 6, 'min_child_samples': 9, 'feature_fraction': 0.7370310060494233, 'bagging_fraction': 0.6393613148799566, 'bagging_freq': 5, 'lambda_l1': 0.013897553011657297, 'lambda_l2': 0.003108745678751362, 'min_gain_to_split': 0.019696811151595287}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:19,105] Trial 63 finished with value: 0.039597397974459124 and parameters: {'num_leaves': 43, 'learning_rate': 0.2458007241129452, 'n_estimators': 374, 'max_depth': 7, 'min_child_samples': 8, 'feature_fraction': 0.5468284879457539, 'bagging_fraction': 0.6762355454653147, 'bagging_freq': 4, 'lambda_l1': 0.01533304554313377, 'lambda_l2': 0.00076573282378117, 'min_gain_to_split': 0.019554168654117784}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:19,483] Trial 64 finished with value: 0.0451782740120318 and parameters: {'num_leaves': 48, 'learning_rate': 0.22374917702814268, 'n_estimators': 359, 'max_depth': 5, 'min_child_samples': 7, 'feature_fraction': 0.7196236899071914, 'bagging_fraction': 0.6103775757254156, 'bagging_freq': 5, 'lambda_l1': 0.020245644158692688, 'lambda_l2': 0.008298536699027942, 'min_gain_to_split': 0.03893267990655551}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:19,903] Trial 65 finished with value: 0.03255079459940465 and parameters: {'num_leaves': 42, 'learning_rate': 0.274430267133215, 'n_estimators': 380, 'max_depth': 8, 'min_child_samples': 8, 'feature_fraction': 0.6957464460678919, 'bagging_fraction': 0.7187988696525237, 'bagging_freq': 5, 'lambda_l1': 0.027874092650768897, 'lambda_l2': 0.00027849618224263443, 'min_gain_to_split': 0.003471384317431038}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:20,339] Trial 66 finished with value: 0.04688257573673709 and parameters: {'num_leaves': 40, 'learning_rate': 0.29977880945762225, 'n_estimators': 393, 'max_depth': 8, 'min_child_samples': 10, 'feature_fraction': 0.6860055523999935, 'bagging_fraction': 0.7608064259825931, 'bagging_freq': 4, 'lambda_l1': 0.028022102120522002, 'lambda_l2': 0.0002592023753654144, 'min_gain_to_split': 0.06771102389762275}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:20,729] Trial 67 finished with value: 0.0458543959662285 and parameters: {'num_leaves': 47, 'learning_rate': 0.28724195927292545, 'n_estimators': 337, 'max_depth': 8, 'min_child_samples': 8, 'feature_fraction': 0.6317301056007337, 'bagging_fraction': 0.7967998445682649, 'bagging_freq': 3, 'lambda_l1': 0.035683644329205615, 'lambda_l2': 0.0002937070403873714, 'min_gain_to_split': 0.05370465679237339}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:21,170] Trial 68 finished with value: 0.0396208107494591 and parameters: {'num_leaves': 50, 'learning_rate': 0.20364266001014025, 'n_estimators': 367, 'max_depth': 7, 'min_child_samples': 11, 'feature_fraction': 0.6636538506409144, 'bagging_fraction': 0.727560567289518, 'bagging_freq': 6, 'lambda_l1': 0.04365596805181928, 'lambda_l2': 0.0007350287139046435, 'min_gain_to_split': 0.01802622821224459}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:23,150] Trial 69 finished with value: 0.04371609887640025 and parameters: {'num_leaves': 45, 'learning_rate': 0.23706579711808573, 'n_estimators': 355, 'max_depth': 8, 'min_child_samples': 9, 'feature_fraction': 0.6115358997860034, 'bagging_fraction': 0.7108371468006063, 'bagging_freq': 5, 'lambda_l1': 1.1335653371027439, 'lambda_l2': 0.003577495330444109, 'min_gain_to_split': 9.371154289061767e-05}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:23,551] Trial 70 finished with value: 0.06124758121474903 and parameters: {'num_leaves': 41, 'learning_rate': 0.17120912765959823, 'n_estimators': 373, 'max_depth': 9, 'min_child_samples': 14, 'feature_fraction': 0.6501840900054094, 'bagging_fraction': 0.5814289234026896, 'bagging_freq': 4, 'lambda_l1': 0.011763290191421673, 'lambda_l2': 0.0065130544758981645, 'min_gain_to_split': 0.19527596989702134}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:23,994] Trial 71 finished with value: 0.029441193279550693 and parameters: {'num_leaves': 42, 'learning_rate': 0.27438701485018324, 'n_estimators': 380, 'max_depth': 6, 'min_child_samples': 7, 'feature_fraction': 0.6944787589164435, 'bagging_fraction': 0.6173772392511964, 'bagging_freq': 5, 'lambda_l1': 0.020850542100826784, 'lambda_l2': 0.0016814597410207228, 'min_gain_to_split': 0.0003116927734103274}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:24,418] Trial 72 finished with value: 0.044411004168867875 and parameters: {'num_leaves': 44, 'learning_rate': 0.2616943130607692, 'n_estimators': 390, 'max_depth': 7, 'min_child_samples': 7, 'feature_fraction': 0.7430730877598799, 'bagging_fraction': 0.6657889304098317, 'bagging_freq': 5, 'lambda_l1': 0.02172641033258491, 'lambda_l2': 0.001434061502125369, 'min_gain_to_split': 0.03753484865810987}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:24,821] Trial 73 finished with value: 0.03876537103940543 and parameters: {'num_leaves': 43, 'learning_rate': 0.2745007146146559, 'n_estimators': 400, 'max_depth': 6, 'min_child_samples': 8, 'feature_fraction': 0.7188755045793399, 'bagging_fraction': 0.6183494188616065, 'bagging_freq': 6, 'lambda_l1': 0.02564781468557218, 'lambda_l2': 0.00013174304979816315, 'min_gain_to_split': 0.01374723356244913}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:25,224] Trial 74 finished with value: 0.04374014126727141 and parameters: {'num_leaves': 47, 'learning_rate': 0.2526291859408934, 'n_estimators': 378, 'max_depth': 5, 'min_child_samples': 6, 'feature_fraction': 0.6934707920850846, 'bagging_fraction': 0.5778256712435701, 'bagging_freq': 5, 'lambda_l1': 0.012488332889151566, 'lambda_l2': 0.002396498679714256, 'min_gain_to_split': 0.03049007566669866}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:25,634] Trial 75 finished with value: 0.030581738395461855 and parameters: {'num_leaves': 41, 'learning_rate': 0.279822890948314, 'n_estimators': 387, 'max_depth': 6, 'min_child_samples': 9, 'feature_fraction': 0.6746876493854479, 'bagging_fraction': 0.5445627203473353, 'bagging_freq': 5, 'lambda_l1': 0.020292728415913133, 'lambda_l2': 0.0004575159072212584, 'min_gain_to_split': 0.0006428889431360802}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:26,039] Trial 76 finished with value: 0.06499951639923972 and parameters: {'num_leaves': 40, 'learning_rate': 0.24412325598910312, 'n_estimators': 389, 'max_depth': 6, 'min_child_samples': 9, 'feature_fraction': 0.6781498538275587, 'bagging_fraction': 0.5505241126104086, 'bagging_freq': 4, 'lambda_l1': 0.010052142644766275, 'lambda_l2': 0.0010489895823555095, 'min_gain_to_split': 0.2767689903970091}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:26,414] Trial 77 finished with value: 0.04926243048708594 and parameters: {'num_leaves': 45, 'learning_rate': 0.2873897883561888, 'n_estimators': 346, 'max_depth': 5, 'min_child_samples': 10, 'feature_fraction': 0.6628724336615114, 'bagging_fraction': 0.5222377854068201, 'bagging_freq': 6, 'lambda_l1': 0.01890600373417609, 'lambda_l2': 0.0003889942659495237, 'min_gain_to_split': 0.05008073753271003}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:26,832] Trial 78 finished with value: 0.07120908996699941 and parameters: {'num_leaves': 41, 'learning_rate': 0.2650612107228723, 'n_estimators': 370, 'max_depth': 6, 'min_child_samples': 7, 'feature_fraction': 0.7277918900031409, 'bagging_fraction': 0.6509422935734922, 'bagging_freq': 4, 'lambda_l1': 0.0323245900559957, 'lambda_l2': 0.009305756685868107, 'min_gain_to_split': 0.4941348575689857}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:27,237] Trial 79 finished with value: 0.055339632778162624 and parameters: {'num_leaves': 47, 'learning_rate': 0.22363970157482022, 'n_estimators': 386, 'max_depth': 7, 'min_child_samples': 12, 'feature_fraction': 0.6150350106384022, 'bagging_fraction': 0.48857195197820247, 'bagging_freq': 5, 'lambda_l1': 0.014463491125620833, 'lambda_l2': 0.0005585123335193216, 'min_gain_to_split': 0.0881741789067443}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:27,626] Trial 80 finished with value: 0.039110808233014584 and parameters: {'num_leaves': 44, 'learning_rate': 0.281883757424932, 'n_estimators': 364, 'max_depth': 6, 'min_child_samples': 11, 'feature_fraction': 0.7794370548308844, 'bagging_fraction': 0.5488333737889465, 'bagging_freq': 4, 'lambda_l1': 0.021331188652840602, 'lambda_l2': 0.0016752143289803423, 'min_gain_to_split': 0.01524174483067087}. Best is trial 54 with value: 0.02890023369751856.
# [I 2024-03-01 19:15:28,090] Trial 81 finished with value: 0.028861115384178713 and parameters: {'num_leaves': 42, 'learning_rate': 0.27507151471651986, 'n_estimators': 377, 'max_depth': 7, 'min_child_samples': 8, 'feature_fraction': 0.6956557669819651, 'bagging_fraction': 0.6804045983019215, 'bagging_freq': 5, 'lambda_l1': 0.027523887584215763, 'lambda_l2': 0.0040742817449583345, 'min_gain_to_split': 0.00011675005229928284}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:28,502] Trial 82 finished with value: 0.043001521795304205 and parameters: {'num_leaves': 41, 'learning_rate': 0.2563978426135587, 'n_estimators': 393, 'max_depth': 7, 'min_child_samples': 9, 'feature_fraction': 0.6401301580224497, 'bagging_fraction': 0.6356392285631295, 'bagging_freq': 5, 'lambda_l1': 0.016929673433536446, 'lambda_l2': 0.003846236964754624, 'min_gain_to_split': 0.030751837378566314}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:28,940] Trial 83 finished with value: 0.030379145844105327 and parameters: {'num_leaves': 42, 'learning_rate': 0.2772620077644939, 'n_estimators': 380, 'max_depth': 5, 'min_child_samples': 7, 'feature_fraction': 0.7157863305501191, 'bagging_fraction': 0.6889478233778751, 'bagging_freq': 5, 'lambda_l1': 0.057677042684336356, 'lambda_l2': 0.01682608784735834, 'min_gain_to_split': 0.0005559370939709464}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:29,395] Trial 84 finished with value: 0.03822221929074824 and parameters: {'num_leaves': 43, 'learning_rate': 0.2930781468900062, 'n_estimators': 375, 'max_depth': 5, 'min_child_samples': 6, 'feature_fraction': 0.6728735708929585, 'bagging_fraction': 0.6821889422925141, 'bagging_freq': 6, 'lambda_l1': 0.011808047920614408, 'lambda_l2': 0.03494064996293293, 'min_gain_to_split': 0.015448808538451198}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:29,793] Trial 85 finished with value: 0.04871190406779435 and parameters: {'num_leaves': 46, 'learning_rate': 0.2773495205174199, 'n_estimators': 357, 'max_depth': 5, 'min_child_samples': 7, 'feature_fraction': 0.7155510084685465, 'bagging_fraction': 0.696154795202632, 'bagging_freq': 5, 'lambda_l1': 0.049239791441400144, 'lambda_l2': 0.015495284568350122, 'min_gain_to_split': 0.06338248364560327}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:30,217] Trial 86 finished with value: 0.04552213609961707 and parameters: {'num_leaves': 42, 'learning_rate': 0.26701050983154845, 'n_estimators': 379, 'max_depth': 6, 'min_child_samples': 8, 'feature_fraction': 0.7437992603148222, 'bagging_fraction': 0.7468302477949237, 'bagging_freq': 5, 'lambda_l1': 0.05906856560586961, 'lambda_l2': 0.002817429479329893, 'min_gain_to_split': 0.045213357161604115}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:30,629] Trial 87 finished with value: 0.04317221302755129 and parameters: {'num_leaves': 49, 'learning_rate': 0.29978995431086, 'n_estimators': 395, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.6559283796497288, 'bagging_fraction': 0.6078559930045615, 'bagging_freq': 5, 'lambda_l1': 0.03681914380862104, 'lambda_l2': 0.0009184042528908513, 'min_gain_to_split': 0.02911589791013925}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:31,025] Trial 88 finished with value: 0.03738051673836841 and parameters: {'num_leaves': 45, 'learning_rate': 0.290670721378475, 'n_estimators': 400, 'max_depth': 4, 'min_child_samples': 7, 'feature_fraction': 0.6847609397875202, 'bagging_fraction': 0.67250066547105, 'bagging_freq': 6, 'lambda_l1': 0.015238072028539638, 'lambda_l2': 0.007527525326479082, 'min_gain_to_split': 0.010621299858624155}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:31,486] Trial 89 finished with value: 0.030259274421315218 and parameters: {'num_leaves': 43, 'learning_rate': 0.25945580441416993, 'n_estimators': 370, 'max_depth': 5, 'min_child_samples': 7, 'feature_fraction': 0.7110926024812024, 'bagging_fraction': 0.6528657804187417, 'bagging_freq': 5, 'lambda_l1': 0.030934463207368236, 'lambda_l2': 0.01135857877475848, 'min_gain_to_split': 0.0007819199186540264}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:31,877] Trial 90 finished with value: 0.04271260930365771 and parameters: {'num_leaves': 44, 'learning_rate': 0.23152143983176915, 'n_estimators': 362, 'max_depth': 5, 'min_child_samples': 9, 'feature_fraction': 0.7538624969586731, 'bagging_fraction': 0.6477217448709732, 'bagging_freq': 5, 'lambda_l1': 0.030419385632226407, 'lambda_l2': 0.03590482996552547, 'min_gain_to_split': 0.028042973130737444}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:32,340] Trial 91 finished with value: 0.030771124329782885 and parameters: {'num_leaves': 43, 'learning_rate': 0.26875858355565674, 'n_estimators': 370, 'max_depth': 6, 'min_child_samples': 7, 'feature_fraction': 0.7236296179431265, 'bagging_fraction': 0.70530165403863, 'bagging_freq': 5, 'lambda_l1': 0.0219908988663867, 'lambda_l2': 0.012214555405041539, 'min_gain_to_split': 0.0011954643718258932}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:32,733] Trial 92 finished with value: 0.03910664672949496 and parameters: {'num_leaves': 42, 'learning_rate': 0.26110249434264393, 'n_estimators': 369, 'max_depth': 5, 'min_child_samples': 6, 'feature_fraction': 0.709788169722025, 'bagging_fraction': 0.6897639705935972, 'bagging_freq': 5, 'lambda_l1': 0.02273306464129406, 'lambda_l2': 0.011466270570611461, 'min_gain_to_split': 0.01764132487368219}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:33,297] Trial 93 finished with value: 0.045928951952187914 and parameters: {'num_leaves': 41, 'learning_rate': 0.2670792216318563, 'n_estimators': 376, 'max_depth': 5, 'min_child_samples': 8, 'feature_fraction': 0.733842220654686, 'bagging_fraction': 0.7084514703682819, 'bagging_freq': 5, 'lambda_l1': 0.03866060326632994, 'lambda_l2': 0.018242619194436947, 'min_gain_to_split': 0.04755273884879352}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:35,012] Trial 94 finished with value: 0.03792561080006877 and parameters: {'num_leaves': 46, 'learning_rate': 0.2807960292847753, 'n_estimators': 371, 'max_depth': 6, 'min_child_samples': 7, 'feature_fraction': 0.7216557737292981, 'bagging_fraction': 0.6601673638947247, 'bagging_freq': 6, 'lambda_l1': 0.02502752457463418, 'lambda_l2': 0.005831258563611759, 'min_gain_to_split': 0.013180180177170785}. Best is trial 81 with value: 0.028861115384178713.
# [I 2024-03-01 19:15:35,608] Trial 95 finished with value: 0.028094592735252864 and parameters: {'num_leaves': 44, 'learning_rate': 0.24759859623131597, 'n_estimators': 385, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.7018745555372053, 'bagging_fraction': 0.6324069166306597, 'bagging_freq': 5, 'lambda_l1': 0.018319799581390715, 'lambda_l2': 0.02570786227424883, 'min_gain_to_split': 1.0389238477655346e-05}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:15:35,996] Trial 96 finished with value: 0.042841956140149864 and parameters: {'num_leaves': 44, 'learning_rate': 0.24783186759451856, 'n_estimators': 387, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.6691765448572878, 'bagging_fraction': 0.616073481759223, 'bagging_freq': 5, 'lambda_l1': 0.013353574628985914, 'lambda_l2': 0.029593189374830013, 'min_gain_to_split': 0.029092218019973096}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:15:36,391] Trial 97 finished with value: 0.04485232303507727 and parameters: {'num_leaves': 41, 'learning_rate': 0.2567654585306649, 'n_estimators': 383, 'max_depth': 4, 'min_child_samples': 5, 'feature_fraction': 0.7076227046376949, 'bagging_fraction': 0.6362199056998256, 'bagging_freq': 4, 'lambda_l1': 0.019361396105869826, 'lambda_l2': 0.09911998673309279, 'min_gain_to_split': 0.04036988038881926}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:15:36,832] Trial 98 finished with value: 0.05227748194145974 and parameters: {'num_leaves': 45, 'learning_rate': 0.23910166964247168, 'n_estimators': 396, 'max_depth': 5, 'min_child_samples': 6, 'feature_fraction': 0.6972909061480361, 'bagging_fraction': 0.6069580905762897, 'bagging_freq': 5, 'lambda_l1': 0.03122902265656895, 'lambda_l2': 0.003393466994641428, 'min_gain_to_split': 0.08168132100228348}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:15:37,252] Trial 99 finished with value: 0.03967984470532168 and parameters: {'num_leaves': 48, 'learning_rate': 0.2590402187020527, 'n_estimators': 390, 'max_depth': 7, 'min_child_samples': 10, 'feature_fraction': 0.6379195991889959, 'bagging_fraction': 0.571931958618629, 'bagging_freq': 6, 'lambda_l1': 0.04673961020560037, 'lambda_l2': 0.06970112900919435, 'min_gain_to_split': 0.011879471030419649}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:15:37,711] Trial 100 finished with value: 0.07261165831576959 and parameters: {'num_leaves': 42, 'learning_rate': 0.2832249701944024, 'n_estimators': 384, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.598265156191665, 'bagging_fraction': 0.5380455800788279, 'bagging_freq': 4, 'lambda_l1': 0.017905598933612973, 'lambda_l2': 0.004247479458047318, 'min_gain_to_split': 0.46473843122357705}. Best is trial 95 with value: 0.028094592735252864.
# ...
# [I 2024-03-01 19:16:11,933] Trial 168 finished with value: 0.06825117528807216 and parameters: {'num_leaves': 43, 'learning_rate': 0.27198519837338064, 'n_estimators': 320, 'max_depth': 6, 'min_child_samples': 15, 'feature_fraction': 0.6852126640935836, 'bagging_fraction': 0.6410373926136402, 'bagging_freq': 5, 'lambda_l1': 0.020077115301534543, 'lambda_l2': 0.0038829142841180653, 'min_gain_to_split': 0.39360723175146717}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:12,424] Trial 169 finished with value: 0.042737976886776115 and parameters: {'num_leaves': 42, 'learning_rate': 0.28483354009387885, 'n_estimators': 364, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.7038461235060799, 'bagging_fraction': 0.6154718872620852, 'bagging_freq': 2, 'lambda_l1': 0.013014244275525985, 'lambda_l2': 0.008902651123404158, 'min_gain_to_split': 0.03334980348796553}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:12,845] Trial 170 finished with value: 0.03755180127311587 and parameters: {'num_leaves': 43, 'learning_rate': 0.26405951739898237, 'n_estimators': 384, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.6741053081203386, 'bagging_fraction': 0.6535590471622738, 'bagging_freq': 5, 'lambda_l1': 0.01684171904374589, 'lambda_l2': 0.005432601266334773, 'min_gain_to_split': 0.01348176440293156}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:13,255] Trial 171 finished with value: 0.03581485191589359 and parameters: {'num_leaves': 46, 'learning_rate': 0.27783351721889804, 'n_estimators': 386, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.6893300658677408, 'bagging_fraction': 0.6018065522413775, 'bagging_freq': 5, 'lambda_l1': 0.021232605813116937, 'lambda_l2': 0.0033612154581885386, 'min_gain_to_split': 0.009196185104991077}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:13,723] Trial 172 finished with value: 0.02870075986651948 and parameters: {'num_leaves': 44, 'learning_rate': 0.25178931351428446, 'n_estimators': 315, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.6035422398272402, 'bagging_fraction': 0.6354443526020535, 'bagging_freq': 5, 'lambda_l1': 0.01866454671240144, 'lambda_l2': 0.006781699841058978, 'min_gain_to_split': 0.0001668465124934602}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:14,109] Trial 173 finished with value: 0.040633750916132534 and parameters: {'num_leaves': 42, 'learning_rate': 0.25270480433833176, 'n_estimators': 309, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.5861317581854705, 'bagging_fraction': 0.6227940413464955, 'bagging_freq': 5, 'lambda_l1': 0.018495945923309172, 'lambda_l2': 0.007172735146617706, 'min_gain_to_split': 0.019367017330045377}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:14,516] Trial 174 finished with value: 0.036004844027328606 and parameters: {'num_leaves': 44, 'learning_rate': 0.2682017806824791, 'n_estimators': 344, 'max_depth': 6, 'min_child_samples': 12, 'feature_fraction': 0.5741380371492317, 'bagging_fraction': 0.6361555986614544, 'bagging_freq': 5, 'lambda_l1': 0.015297377291646177, 'lambda_l2': 0.0097317842816235, 'min_gain_to_split': 0.009481964600712593}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:14,955] Trial 175 finished with value: 0.029232246938756652 and parameters: {'num_leaves': 59, 'learning_rate': 0.24851081158559113, 'n_estimators': 337, 'max_depth': 5, 'min_child_samples': 6, 'feature_fraction': 0.6985641679582015, 'bagging_fraction': 0.671231985128213, 'bagging_freq': 5, 'lambda_l1': 0.01956119199964809, 'lambda_l2': 0.004200007364337924, 'min_gain_to_split': 0.00034324100993916986}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:15,368] Trial 176 finished with value: 0.04219653299886239 and parameters: {'num_leaves': 57, 'learning_rate': 0.24531973235919755, 'n_estimators': 334, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.60772102733551, 'bagging_fraction': 0.6593399598918405, 'bagging_freq': 6, 'lambda_l1': 0.010081748349577046, 'lambda_l2': 0.002756597246269149, 'min_gain_to_split': 0.027495472982597184}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:15,812] Trial 177 finished with value: 0.029462461235657857 and parameters: {'num_leaves': 45, 'learning_rate': 0.24999136702509814, 'n_estimators': 338, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.6796977672293245, 'bagging_fraction': 0.6735973114075752, 'bagging_freq': 5, 'lambda_l1': 0.02008902970593713, 'lambda_l2': 0.004838452689952181, 'min_gain_to_split': 0.0004669325054906544}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:16,309] Trial 178 finished with value: 0.0284415141705778 and parameters: {'num_leaves': 45, 'learning_rate': 0.23649204525602005, 'n_estimators': 338, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.595127661233207, 'bagging_fraction': 0.6742655113936926, 'bagging_freq': 5, 'lambda_l1': 0.017523411772321258, 'lambda_l2': 0.004397612234953556, 'min_gain_to_split': 4.544716475080379e-05}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:16,722] Trial 179 finished with value: 0.03845616480662537 and parameters: {'num_leaves': 76, 'learning_rate': 0.2347052665582553, 'n_estimators': 329, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.5925732216596231, 'bagging_fraction': 0.6737964148844339, 'bagging_freq': 5, 'lambda_l1': 0.017447890932052165, 'lambda_l2': 0.004245714384571797, 'min_gain_to_split': 0.0162626317920454}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:17,114] Trial 180 finished with value: 0.03654931108310121 and parameters: {'num_leaves': 46, 'learning_rate': 0.22701249955221006, 'n_estimators': 338, 'max_depth': 5, 'min_child_samples': 6, 'feature_fraction': 0.5950935281057208, 'bagging_fraction': 0.6690574141381561, 'bagging_freq': 5, 'lambda_l1': 0.022900623400744217, 'lambda_l2': 0.004673743622994015, 'min_gain_to_split': 0.010066062647941338}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:17,583] Trial 181 finished with value: 0.02936234393126674 and parameters: {'num_leaves': 59, 'learning_rate': 0.23949019140371483, 'n_estimators': 341, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.698485490923178, 'bagging_fraction': 0.6823125262717296, 'bagging_freq': 5, 'lambda_l1': 0.013652010449267294, 'lambda_l2': 0.006621445903787815, 'min_gain_to_split': 0.0005682861408340739}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:18,032] Trial 182 finished with value: 0.02926954866085166 and parameters: {'num_leaves': 60, 'learning_rate': 0.2474279952752188, 'n_estimators': 340, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.5623229254640482, 'bagging_fraction': 0.6833913124623467, 'bagging_freq': 5, 'lambda_l1': 0.013652872852719563, 'lambda_l2': 0.0034589952294937507, 'min_gain_to_split': 0.00045680001147164676}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:18,465] Trial 183 finished with value: 0.040244278353260006 and parameters: {'num_leaves': 60, 'learning_rate': 0.24864474524739763, 'n_estimators': 341, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.5596108048696206, 'bagging_fraction': 0.6870950731645005, 'bagging_freq': 5, 'lambda_l1': 0.01953701150330696, 'lambda_l2': 0.003810867529180398, 'min_gain_to_split': 0.02150598306310932}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:18,868] Trial 184 finished with value: 0.035910882710001514 and parameters: {'num_leaves': 59, 'learning_rate': 0.23794237932757573, 'n_estimators': 338, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.5410537929242395, 'bagging_fraction': 0.6835689812106583, 'bagging_freq': 5, 'lambda_l1': 0.01636524925026592, 'lambda_l2': 0.005126921106449696, 'min_gain_to_split': 0.009593926890980474}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:19,253] Trial 185 finished with value: 0.03647929050681956 and parameters: {'num_leaves': 59, 'learning_rate': 0.24155307368884135, 'n_estimators': 349, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.5378217530422511, 'bagging_fraction': 0.6520967597342315, 'bagging_freq': 5, 'lambda_l1': 0.013885931011989879, 'lambda_l2': 0.007904266099561017, 'min_gain_to_split': 0.010653209605781646}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:19,722] Trial 186 finished with value: 0.028652504269931992 and parameters: {'num_leaves': 60, 'learning_rate': 0.2525287420574116, 'n_estimators': 332, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.6134641607665067, 'bagging_fraction': 0.6685553692561639, 'bagging_freq': 5, 'lambda_l1': 0.01785523069800062, 'lambda_l2': 0.013061066829670363, 'min_gain_to_split': 0.00011249936075119204}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:20,113] Trial 187 finished with value: 0.041975222695529044 and parameters: {'num_leaves': 60, 'learning_rate': 0.23034753388716944, 'n_estimators': 333, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.6050823087006932, 'bagging_fraction': 0.665515387935692, 'bagging_freq': 5, 'lambda_l1': 0.02085801707392407, 'lambda_l2': 0.009145888924024946, 'min_gain_to_split': 0.02539100516000661}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:22,022] Trial 188 finished with value: 0.03968891326655133 and parameters: {'num_leaves': 62, 'learning_rate': 0.24793000005185845, 'n_estimators': 343, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.5789151533294574, 'bagging_fraction': 0.6761070875640017, 'bagging_freq': 5, 'lambda_l1': 0.01778684908748172, 'lambda_l2': 0.01279129772912915, 'min_gain_to_split': 0.0176173103059088}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:22,537] Trial 189 finished with value: 0.028925512617357478 and parameters: {'num_leaves': 55, 'learning_rate': 0.239365510180728, 'n_estimators': 323, 'max_depth': 5, 'min_child_samples': 6, 'feature_fraction': 0.5627008614682241, 'bagging_fraction': 0.648609885398516, 'bagging_freq': 5, 'lambda_l1': 0.023247695923285905, 'lambda_l2': 0.012424650362575623, 'min_gain_to_split': 0.00013266895768541197}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:22,923] Trial 190 finished with value: 0.05672561120706206 and parameters: {'num_leaves': 58, 'learning_rate': 0.22100488664960236, 'n_estimators': 330, 'max_depth': 5, 'min_child_samples': 6, 'feature_fraction': 0.5483372663532067, 'bagging_fraction': 0.6459970906631681, 'bagging_freq': 5, 'lambda_l1': 1.396585714691471, 'lambda_l2': 0.015896777881106067, 'min_gain_to_split': 0.04221063605503716}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:23,321] Trial 191 finished with value: 0.035491979271915344 and parameters: {'num_leaves': 55, 'learning_rate': 0.2418034173687601, 'n_estimators': 326, 'max_depth': 5, 'min_child_samples': 6, 'feature_fraction': 0.5752963968689672, 'bagging_fraction': 0.6551369146564249, 'bagging_freq': 5, 'lambda_l1': 0.02366881825322041, 'lambda_l2': 0.012301442774703608, 'min_gain_to_split': 0.008164076820454001}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:23,751] Trial 192 finished with value: 0.029701514543132423 and parameters: {'num_leaves': 62, 'learning_rate': 0.25362764354297934, 'n_estimators': 314, 'max_depth': 5, 'min_child_samples': 6, 'feature_fraction': 0.5616322514330536, 'bagging_fraction': 0.6619153827776545, 'bagging_freq': 5, 'lambda_l1': 0.0195045443209221, 'lambda_l2': 0.006834798305230702, 'min_gain_to_split': 0.000550149557692987}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:24,157] Trial 193 finished with value: 0.03567124384607782 and parameters: {'num_leaves': 58, 'learning_rate': 0.23823083310732437, 'n_estimators': 324, 'max_depth': 6, 'min_child_samples': 6, 'feature_fraction': 0.5690620767625819, 'bagging_fraction': 0.6764706794487896, 'bagging_freq': 5, 'lambda_l1': 0.02189242368044509, 'lambda_l2': 0.00958353147064351, 'min_gain_to_split': 0.0094776256752293}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:24,638] Trial 194 finished with value: 0.028876507842492367 and parameters: {'num_leaves': 57, 'learning_rate': 0.24801739859005092, 'n_estimators': 336, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.6031255571960209, 'bagging_fraction': 0.6415232312695002, 'bagging_freq': 5, 'lambda_l1': 0.024791380073043438, 'lambda_l2': 0.0046222688398529915, 'min_gain_to_split': 0.00014659694987417178}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:25,029] Trial 195 finished with value: 0.03942166509411048 and parameters: {'num_leaves': 59, 'learning_rate': 0.24832494640194103, 'n_estimators': 335, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.5983652591392833, 'bagging_fraction': 0.6297011341435447, 'bagging_freq': 5, 'lambda_l1': 0.01562626666807405, 'lambda_l2': 0.005716961779142967, 'min_gain_to_split': 0.01757184443963996}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:25,421] Trial 196 finished with value: 0.04374610582646871 and parameters: {'num_leaves': 57, 'learning_rate': 0.2343379401106553, 'n_estimators': 348, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.5255992486379307, 'bagging_fraction': 0.6483189946114399, 'bagging_freq': 5, 'lambda_l1': 0.02608807156899289, 'lambda_l2': 0.020174793084239872, 'min_gain_to_split': 0.02929905992961597}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:25,860] Trial 197 finished with value: 0.02997046095884408 and parameters: {'num_leaves': 58, 'learning_rate': 0.2554516422749984, 'n_estimators': 339, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.6108710932504102, 'bagging_fraction': 0.6401288404746495, 'bagging_freq': 5, 'lambda_l1': 0.018433590058815282, 'lambda_l2': 0.0034429204214659107, 'min_gain_to_split': 0.0010107742217348433}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:26,392] Trial 198 finished with value: 0.028198735428867965 and parameters: {'num_leaves': 60, 'learning_rate': 0.2441028398320282, 'n_estimators': 324, 'max_depth': 5, 'min_child_samples': 6, 'feature_fraction': 0.5535571086254649, 'bagging_fraction': 0.6599652051672326, 'bagging_freq': 5, 'lambda_l1': 0.023731738228118398, 'lambda_l2': 0.8348868213341152, 'min_gain_to_split': 1.2377407797125726e-05}. Best is trial 95 with value: 0.028094592735252864.
# [I 2024-03-01 19:16:26,782] Trial 199 finished with value: 0.039058489559643736 and parameters: {'num_leaves': 60, 'learning_rate': 0.24168153210858515, 'n_estimators': 323, 'max_depth': 5, 'min_child_samples': 6, 'feature_fraction': 0.557365941776512, 'bagging_fraction': 0.6248310143596955, 'bagging_freq': 5, 'lambda_l1': 0.02506867421372914, 'lambda_l2': 0.011914145994267437, 'min_gain_to_split': 0.016327799307655048}. Best is trial 95 with value: 0.028094592735252864.
# Best trial: 95
# Best MAE: 0.028094592735252864
# Best hyperparameters: {'num_leaves': 44, 'learning_rate': 0.24759859623131597, 'n_estimators': 385, 'max_depth': 6, 'min_child_samples': 5, 'feature_fraction': 0.7018745555372053, 'bagging_fraction': 0.6324069166306597, 'bagging_freq': 5, 'lambda_l1': 0.018319799581390715, 'lambda_l2': 0.02570786227424883, 'min_gain_to_split': 1.0389238477655346e-05}
